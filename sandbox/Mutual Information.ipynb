# %%
import pandas as pd
import glob
import numpy as np
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score

from sklearn.feature_selection import mutual_info_classif

# %%
df = pd.read_csv('../data/others/parkinsons.csv')

# %%
## dropping columns
dropcols=['name']
df.drop(dropcols, axis=1, inplace=True)

# %%
## train-test split
X = df.drop(['status'], axis=1)
y = df['status']

train_size=0.80
test_size=0.20
seed=5

X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=train_size,test_size=test_size,random_state=seed)

# %%
## training the model
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print('Macro: ', precision_score(y_test, rfc.predict(X_test), average='macro'))
print('Micro: ', precision_score(y_test, rfc.predict(X_test), average='micro'))
print('Weighted: ', precision_score(y_test, rfc.predict(X_test), average='weighted'))
# Out:
# Macro:  0.9111111111111111
# Micro:  0.9230769230769231
# Weighted:  0.9219373219373219

# %%
## mutual information testing
mutual_info_classif(X, y)
# Out:
# array([0.20659267, 0.14071299, 0.17408837, 0.11429049, 0.1518194 ,
#        0.10784183, 0.10114217, 0.08646014, 0.10150426, 0.12124283,
#        0.11231623, 0.11373436, 0.18607842, 0.10872648, 0.11675419,
#        0.13246159, 0.03700343, 0.09511555, 0.22136783, 0.19200151,
#        0.01791333, 0.25398246])

# %%
for fi in df.columns:
    for fj in df.columns:
        for fz in df.columns:
            print('Class name: ', featurename, 'Cond on ', fj)
            print( cmi([fi], ['class'], [fj, fz], 5, df) )
            print('---------------------------')
# Out:
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  MDVP:RAP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  MDVP:PPQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  Jitter:DDP
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Shimmer(dB)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ3
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  Shimmer:APQ5
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423621134666895
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002162471600778491
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002537123820840711
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.0021547083023108872
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.002423899365148849
# ---------------------------
# Class name:  PPE Cond on  MDVP:APQ
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0018597441165591195
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.00226557857520305
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0018660412065952022
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021030450238815374
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0021027609049237657
# ---------------------------
# Class name:  PPE Cond on  spread2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.6980056980056774e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 5.5741360089183007e-05
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Fhi(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Flo(Hz)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013425356801833506
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00017832209439411703
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00014405979978646108
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.00010712020755163985
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(%)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.00013369121857860952
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# 0.0
# ---------------------------
# Class name:  PPE Cond on  MDVP:Jitter(Abs)
# ...
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  Shimmer:DDA
# 2.068009830630642
# ---------------------------
# Class name:  PPE Cond on  Shimmer:DDA
# 1.3351044738594755
# ---------------------------
# Class name:  PPE Cond on  Shimmer:DDA
# 1.5288297810475424
# ---------------------------
# Class name:  PPE Cond on  Shimmer:DDA
# 0.009059829059829067
# ---------------------------
# Class name:  PPE Cond on  Shimmer:DDA
# 1.3937793610989448
# ---------------------------
# Class name:  PPE Cond on  Shimmer:DDA
# 0.9475618313599379
# ---------------------------
# Class name:  PPE Cond on  Shimmer:DDA
# 0.0
# ---------------------------
# Class name:  PPE Cond on  NHR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  NHR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  NHR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.6148245638091754
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.626300721234804
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.626224180859756
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.62373033654576
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.5790961563923855
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.3183434690845655
# ---------------------------
# Class name:  PPE Cond on  NHR
# 1.4053931211516495
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.466750104270814
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.4477620297226252
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.379742749082881
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.130383350085549
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.626300721234804
# ---------------------------
# Class name:  PPE Cond on  NHR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  NHR
# 2.254477883628875
# ---------------------------
# Class name:  PPE Cond on  NHR
# 1.4214834451640028
# ---------------------------
# Class name:  PPE Cond on  NHR
# 1.5765655086529153
# ---------------------------
# Class name:  PPE Cond on  NHR
# 0.010085470085470094
# ---------------------------
# Class name:  PPE Cond on  NHR
# 1.4857900161935171
# ---------------------------
# Class name:  PPE Cond on  NHR
# 0.9830382895145476
# ---------------------------
# Class name:  PPE Cond on  NHR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.02791208791208793
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.05934065934065935
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.017435897435897452
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.04561660561660564
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.04715506715506716
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.02927960927960929
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.0030769230769230795
# ---------------------------
# Class name:  PPE Cond on  HNR
# 0.0
# ---------------------------
# Class name:  PPE Cond on  status
# 0.0
# ---------------------------
# Class name:  PPE Cond on  status
# 0.0
# ---------------------------
# Class name:  PPE Cond on  status
# 0.0
# ---------------------------
# Class name:  PPE Cond on  status
# 2.9407364990722247
# ---------------------------
# Class name:  PPE Cond on  status
# 3.19327110050494
# ---------------------------
# Class name:  PPE Cond on  status
# 3.0726164855192635
# ---------------------------
# Class name:  PPE Cond on  status
# 3.078275453252987
# ---------------------------
# Class name:  PPE Cond on  status
# 2.7714085795434604
# ---------------------------
# Class name:  PPE Cond on  status
# 2.3162308068428534
# ---------------------------
# Class name:  PPE Cond on  status
# 1.1350031792232962
# ---------------------------
# Class name:  PPE Cond on  status
# 2.563562204910193
# ---------------------------
# Class name:  PPE Cond on  status
# 2.5376992388514634
# ---------------------------
# Class name:  PPE Cond on  status
# 2.427005471095014
# ---------------------------
# Class name:  PPE Cond on  status
# 2.068009830630642
# ---------------------------
# Class name:  PPE Cond on  status
# 2.254477883628875
# ---------------------------
# Class name:  PPE Cond on  status
# 0.017435897435897452
# ---------------------------
# Class name:  PPE Cond on  status
# 3.19327110050494
# ---------------------------
# Class name:  PPE Cond on  status
# 1.2614943400105465
# ---------------------------
# Class name:  PPE Cond on  status
# 1.6177765633685972
# ---------------------------
# Class name:  PPE Cond on  status
# 0.008034188034188039
# ---------------------------
# Class name:  PPE Cond on  status
# 1.4427165648132851
# ---------------------------
# Class name:  PPE Cond on  status
# 0.7265892538307746
# ---------------------------
# Class name:  PPE Cond on  status
# 0.0
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.612794605235737
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.6221335957293908
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.619263872859668
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.6187561398519352
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.5909035325662186
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.475027364235897
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 0.7805222008973783
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.5810119837018295
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.5511720230868185
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.5138758816611388
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.3351044738594755
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 1.4214834451640028
# ---------------------------
# Class name:  PPE Cond on  RPDE
# 0.04561660561660564
# ---------------------------
# Class name:  PPE Cond on  RPDE
#
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.6702780097240969
# ---------------------------
# Class name:  PPE Cond on  spread2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0588515115470107
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0588515115470107
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0588515115470107
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0588515115470107
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0563871240826228
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0313985764267737
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.42241341645485575
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0556948320441772
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0523026117288803
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.047959291231713
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.9475618313599379
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.9830382895145476
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0030769230769230795
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.7265892538307746
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.5199243532126542
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.7583312194464634
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.6702780097240969
# ---------------------------
# Class name:  PPE Cond on  D2
# 1.0588515115470107
# ---------------------------
# Class name:  PPE Cond on  D2
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------
# Class name:  PPE Cond on  PPE
# 0.0
# ---------------------------

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['slength', 'swidth', 'plength', 'pwidth', 'class']
df = pd.read_csv(url, names=names)
print(cmi(['pwidth'], ['class'], ['swidth'], 5, df))
print(cmi(['pwidth'], ['class'], ['plength'], 5, df))
print(cmi(['pwidth'], ['class'], ['swidth', 'plength'], 5, df))
# Out:
# 0.7717299894796478
# 0.04794217643508005
# 0.04829176722230071

# %%
###  Author: Octavio Mesner
###  This code should be able to compute
###  Conditional Mutual Information using kNN

import numpy as np
import pandas as pd
from scipy.special import digamma

# If a variable is categorical, M/F eg, we must define a distance
# if not equal
# might need to be changed to something else later

def getPairwiseDistArray(data, coords = [], discrete_dist = 1):
    '''
    Input: 
    data: pandas data frame
    coords: list of indices for variables to be used
    discrete_dist: distance to be used for non-numeric differences
    Output:
    p x n x n array with pairwise distances for each variable
    '''
    n, p = data.shape
    if coords == []:
        coords = range(p)
    col_names = list(data)
    distArray = np.empty([p,n,n])
    distArray[:] = np.nan
    for coord in coords:
        thisdtype=data[col_names[coord]].dtype
        if pd.api.types.is_numeric_dtype(thisdtype):
            distArray[coord,:,:] = abs(data[col_names[coord]].to_numpy() -
                                       data[col_names[coord]].to_numpy()[:,None])
        else:
            distArray[coord,:,:] = (1 - (data[col_names[coord]].to_numpy() ==
                                    data[col_names[coord]].to_numpy()[:,None])) * discrete_dist
    return distArray

def getPointCoordDists(distArray, ind_i, coords = list()):
    '''
    Input: 
    ind_i: current observation row index
    distArray: output from getPariwiseDistArray
    coords: list of variable (column) indices
    output: n x p matrix of all distancs for row ind_i
    '''
    if not coords:
        coords = range(distArray.shape[0])
    obsDists = np.transpose(distArray[coords, :, ind_i])
    return obsDists

def countNeighbors(coord_dists, rho, coords = list()):
    '''
    input: list of coordinate distances (output of coordDistList), 
    coordinates we want (coords), distance (rho)
    output: scalar integer of number of points within ell infinity radius
    '''
    
    if not coords:
        coords = range(coord_dists.shape[1])
    dists = np.max(coord_dists[:,coords], axis = 1)
    count = np.count_nonzero(dists <= rho) - 1
    return count

def getKnnDist(distArray, k):
    '''
    input:
    distArray: numpy 2D array of pairwise, coordinate wise distances,
    output from getPairwiseDistArray
    k: nearest neighbor value
    
    output: (k, distance to knn)
    '''
    dists = np.max(distArray, axis = 1)
    ordered_dists = np.sort(dists)
    # using k, not k-1, here because this includes dist to self
    k_tilde = np.count_nonzero(dists <= ordered_dists[k]) - 1
    return k_tilde, ordered_dists[k]

def cmiPoint(point_i, x, y, z, k, distArray):
    '''
    input:
    point_i: current observation row index
    x, y, z: list of indices
    k: positive integer scalar for k in knn
    distArray: output of getPairwiseDistArray
    output:
    cmi point estimate
    '''
    n = distArray.shape[1]
    coord_dists = getPointCoordDists(distArray, point_i, x + y + z)
    k_tilde, rho = getKnnDist(coord_dists, k)
    x_coords = list(range(len(x)))
    y_coords = list(range(len(x), len(x+y)))
    z_coords = list(range(len(x+y), len(x+y+z)))
    nxz = countNeighbors(coord_dists, rho, x_coords + z_coords)
    nyz = countNeighbors(coord_dists, rho, y_coords + z_coords)
    nz = countNeighbors(coord_dists, rho, z_coords)
    xi = digamma(k_tilde) - digamma(nxz) - digamma(nyz) + digamma(nz)
    return xi

def miPoint(point_i, x, y, k, distArray):
    '''
    input:
    point_i: current observation row index
    x, y: list of indices
    k: positive integer scalar for k in knn
    distArray: output of getPairwiseDistArray
    output:
    mi point estimate
    '''
    n = distArray.shape[1]
    coord_dists = getPointCoordDists(distArray, point_i, x + y)
    k_tilde, rho = getKnnDist(coord_dists, k)
    x_coords = list(range(len(x)))
    y_coords = list(range(len(x), len(x+y)))
    nx = countNeighbors(coord_dists, rho, x_coords)
    ny = countNeighbors(coord_dists, rho, y_coords)
    xi = digamma(k_tilde) + digamma(n) - digamma(nx) - digamma(ny)
    return xi
    
def cmi(x, y, z, k, data, discrete_dist = 1, minzero = 1):
    '''
    computes conditional mutual information, I(x,y|z)
    input:
    x: list of indices for x
    y: list of indices for y
    z: list of indices for z
    k: hyper parameter for kNN
    data: pandas dataframe
    output:
    scalar value of I(x,y|z)
    '''
    # compute CMI for I(x,y|z) using k-NN
    n, p = data.shape

    # convert variable to index if not already
    vrbls = [x,y,z]
    for i, lst in enumerate(vrbls):
        if all(type(elem) == str for elem in lst) and len(lst) > 0:
            vrbls[i] = list(data.columns.get_indexer(lst))
    x,y,z = vrbls
            
    distArray = getPairwiseDistArray(data, x + y + z, discrete_dist)
    if len(z) > 0:
        ptEsts = map(lambda obs: cmiPoint(obs, x, y, z, k, distArray), range(n))
    else:
        ptEsts = map(lambda obs: miPoint(obs, x, y, k, distArray), range(n))
    if minzero == 1:
        return(max(sum(ptEsts)/n,0))
    elif minzero == 0:
        return(sum(ptEsts)/n)
